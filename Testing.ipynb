# %%
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
frame = pd.DataFrame.from_csv('../data/indice/frame.csv')
frame.head()
# Out:
#                  spy  spy_lag1      sp500     nasdaq        dji       cac40  \
# Date
# 2008-01-04 -1.529998 -1.570008  -3.540039 -40.879883    2.43945    5.489746
# 2008-01-07  0.270004 -1.529998 -29.940064 -56.930176 -245.40918 -111.689941
# 2008-01-08 -2.990006  0.270004   1.640015  -7.179931   19.75000   44.509766
# 2008-01-09  0.589997 -2.990006 -25.459961 -63.119873 -230.69043  -17.109864
# 2008-01-10  1.100006  0.589997  16.530029   8.270019  142.90039    9.140137
#
#                   daxi        aord         hsi      nikkei       Price
# Date
# 2008-01-04  -27.990235   -2.300293  515.349609 -464.320313  143.339996
# 2008-01-07 -102.709961  -27.500000  216.951171  -48.830078  141.809998
# 2008-01-08   33.680176  -33.899902 -354.060547   99.370117  142.080002
# 2008-01-09   -5.270020  -12.900390  768.359375  234.450195  139.089996
# 2008-01-10  -40.120117 -100.200196 -195.560547 -158.209961  139.679993

# %%
Train = frame.iloc[-2000:-1000, :]
Test = frame.iloc[-1000:, :]

# %%
formula = 'spy~spy_lag1+sp500+nasdaq+dji+cac40+aord+daxi+nikkei+hsi'
lm = smf.ols(formula=formula, data=Train).fit()

# %%
Train['PredictedY'] = lm.predict(Train)
Test['PredictedY'] = lm.predict(Test)

# %%
# Train
Train['Order'] = [1 if sig>0 else -1 for sig in Train['PredictedY']]
Train['Profit'] = Train['spy'] * Train['Order']

Train['Wealth'] = Train['Profit'].cumsum()
print('Total profit made in Train: ', Train['Profit'].sum())
# Out:
# Total profit made in Train:  214.340095

# %%
plt.figure(figsize=(10, 10))
plt.title('Performance of Strategy in Train')
plt.plot(Train['Wealth'].values, color='green', label='Signal')
plt.plot(Train['spy'].cumsum().values, color='red', label='BHS')
plt.legend()
plt.show()

# %%
# Test
Test['Order'] = [1 if sig>0 else -1 for sig in Test['PredictedY']]
Test['Profit'] = Test['spy'] * Test['Order']

Test['Wealth'] = Test['Profit'].cumsum()
print('Total profit made in Test: ', Test['Profit'].sum())
# Out:
# Total profit made in Test:  241.030088

# %%
plt.figure(figsize=(10, 10))
plt.title('Performance of Strategy in Train')
plt.plot(Test['Wealth'].values, color='green', label='Signal')
plt.plot(Test['spy'].cumsum().values, color='red', label='BHS')
plt.legend()
plt.show()

# %%
Train['Wealth'] = Train['Wealth'] + Train.loc[Train.index[0], 'Price']
Test['Wealth'] = Test['Wealth'] + Test.loc[Test.index[0], 'Price']

# %%
# Sharpe Ratio on Train data
Train['Return'] = np.log(Train['Wealth']) - np.log(Train['Wealth'].shift(1))
dailyr = Train['Return'].dropna()

print('Daily Sharpe Ratio is ', dailyr.mean()/dailyr.std(ddof=1))
print('Yearly Sharpe Ratio is ', (252**0.5)*dailyr.mean()/dailyr.std(ddof=1))
# Out:
# Daily Sharpe Ratio is  0.179650763033
# Yearly Sharpe Ratio is  2.85186745096

# %%
# Sharpe Ratio in Test data
Test['Return'] = np.log(Test['Wealth']) - np.log(Test['Wealth'].shift(1))
dailyr = Test['Return'].dropna()

print('Daily Sharpe Ratio is ', dailyr.mean()/dailyr.std(ddof=1))
print('Yearly Sharpe Ratio is ', (252**0.5)*dailyr.mean()/dailyr.std(ddof=1))
# Out:
# Daily Sharpe Ratio is  0.130351262086
# Yearly Sharpe Ratio is  2.06926213537

# %%
# Maximum Drawdown in Train data
Train['Peak'] = Train['Wealth'].cummax()
Train['Drawdown'] = (Train['Peak'] - Train['Wealth'])/Train['Peak']
print('Maximum Drawdown in Train is ', Train['Drawdown'].max())
# Out:
# Maximum Drawdown in Train is  0.0606901644364

# %%
# Maximum Drawdown in Test data
Test['Peak'] = Test['Wealth'].cummax()
Test['Drawdown'] = (Test['Peak'] - Test['Wealth'])/Test['Peak']
print('Maximum Drawdown in Test is ', Test['Drawdown'].max())
# Out:
# Maximum Drawdown in Test is  0.117198995246
